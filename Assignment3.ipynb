# %% [markdown]
# <a href="https://colab.research.google.com/github/Praveenpadidapu/ML-Assignments/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #plot a simple line graph of 𝑦 = 𝑥2 for 𝑥 values ranging from -10 to 10.  Label the x-axis as "X Values" and the y-axis as "Squared Values." o Add a title to the graph.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-10, 11)
y = x**2

plt.plot(x, y)
plt.xlabel('X values')
plt.ylabel('Squared Values')
plt.title('Square of X')
plt.show()

# %% [markdown]
# #Create a bar chart showing the marks scored by 5 students: [Sai, 'Vamsi', 'Divij', 'Sritan', 'Sita'] with marks [85, 90, 78, 92, 88]. o Add labels to the x-axis and y-axis and give the chart a title.

# %%
import matplotlib.pyplot as plt
Students=['Sai', 'Vamsi', 'Divij', 'Sritan', 'Sita']
Marks=[85, 90, 78, 92, 88]
plt.bar(Students, Marks)
plt.xlabel('Students Name')
plt.ylabel('Marks Secured')
plt.title('Results')
plt.show()

# %% [markdown]
# #Generate two lists of 20 random integers each (for x and y coordinates).
# #o Create a scatter plot with these values, and customize it by adding color,
# #size, and labels to the points.

# %%
import numpy as np
import matplotlib.pyplot as plt
data1=np.random.randint(0,150,15)
data2=np.random.randint(0,150,15)
plt.scatter(data1,data2,c='orange')
#labeling
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.title("Scatter plot")
plt.show()

# %% [markdown]
# #o Simulate 100 random values from a normal distribution using
# #np.random.randn() and plot a histogram.
# #o Customize the number of bins and add a grid to the plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
data=np.random.randn(120)
plt.hist(data,bins=10)
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.title("Histogram plot")
plt.grid()
plt.show()

# %% [markdown]
# # Visualize the percentage distribution of five categories ['A', 'B', 'C', 'D', 'E']
# #with values [20, 30, 25, 15, 10].
# # Display the percentage values on the chart and use a color palette for
# #differentiation.

# %%
import numpy as np
import matplotlib.pyplot as plt
data=[20,30,25,15,10]
index=['A','B','C','D','E']
plt.pie(data,labels=index,autopct='%1.1d%%')#gives integers
plt.show()

# %% [markdown]
# #Create a box plot to visualize the distribution of the marks scored by
# #students in a class: [78, 85, 92, 88, 76, 95, 89, 84, 91, 73].
# #o Highlight the median and any outliers.

# %%
import numpy as np
import matplotlib.pyplot as plt
students=[78, 85, 92, 88, 76, 95, 89, 84, 91, 73]
plt.boxplot(students)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title("Box plot")
plt.show()

# %% [markdown]
# #Create a 5x5 matrix with random integers between 1 and 10 using
# #np.random.randint() and visualize it as a heatmap using Sea

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
matrix=np.random.randint(1,11, size=(5,5))
sns.heatmap(matrix,annot=True,cmap='PuBuGn')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title("Heat map")
plt.show()

# %% [markdown]
# #Generate a pair of plots (bar charts or line plots) using the same data in
# #both Matplotlib and Seaborn.
# # Highlight the differences in the code, syntax, and aesthetics of the two
# #libraries.

# %% [markdown]
# **Difference**

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = {'Students': ['Sai','Vamsi', 'Divij', 'Sritan', 'Sita'],
        'Marks': [85, 90, 78, 92, 88]}
df = pd.DataFrame(data)
df = df.set_index('Students')
sns.heatmap(df, annot=True, cmap='PuBuGn')
plt.xlabel('Students Name')
plt.ylabel('Marks Secured')
plt.title('Seaborn Heatmap')
plt.show()

# %%
import matplotlib.pyplot as plt
Students=['Sai','Vamsi', 'Divij', 'Sritan', 'Sita']
Marks=[85, 90, 78, 92, 88]
plt.bar(Students,Marks)
plt.xlabel("Categories")
plt.ylabel("Values")
plt.title("Bar Chart using Matplotlib")
plt.show()

# %% [markdown]
# #Manually create a small dataset with columns such as 'Age', 'Height',
# #'Weight' for 10 individuals and visualize the relationships using a pair plot.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data = {'Age': [25, 30, 22, 35, 28, 20, 32, 27, 31, 29],
        'Height': [175, 180, 165, 185, 172, 160, 182, 170, 183, 178],
        'Weight': [70, 75, 60, 80, 68, 55, 78, 65, 82, 72]}
df = pd.DataFrame(data)
sns.pairplot(df)
plt.show()
