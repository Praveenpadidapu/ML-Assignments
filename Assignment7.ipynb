# %% [markdown]
# <a href="https://colab.research.google.com/github/Praveenpadidapu/ML-Assignments/blob/main/Assignment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data=pd.read_csv('/content/Ecommerce_Sales_Prediction_Dataset.csv')
data.sample(10)
# Out:
#            Date Product_Category   Price  Discount Customer_Segment  \
# 12   13-01-2023             Toys  456.33      8.71       Occasional
# 787  26-02-2025           Sports  501.80     22.47          Premium
# 294  22-10-2023           Sports  943.30     38.78          Regular
# 908  27-06-2025      Electronics  445.12     38.51          Regular
# 331  28-11-2023          Fashion  414.37      8.30          Regular
# 120    1/5/2023          Fashion  301.52     44.31          Premium
# 957  15-08-2025             Toys  248.79     17.26       Occasional
# 431    7/3/2024      Electronics  281.47     29.92       Occasional
# 506  21-05-2024           Sports   61.45     25.63          Premium
# 609    1/9/2024      Electronics  479.88     30.29       Occasional
#
#      Marketing_Spend  Units_Sold
# 12           6033.09          37
# 787          7050.86          25
# 294          2203.23          38
# 908          1929.90          27
# 331           207.03          46
# ...

# %%
#get data directly from scikit-learn
X, y = load_digits(return_X_y=True)

# %%
X.shape, y.shape
# Out:
# ((1797, 64), (1797,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train[0], np.mean(X_train[0]), np.std(X_train[0])
# Out:
# (array([ 0.,  0.,  0.,  9., 15.,  2.,  0.,  0.,  0.,  0.,  5., 16., 11.,
#          1.,  0.,  0.,  0.,  0., 13., 15.,  1.,  0.,  0.,  0.,  0.,  2.,
#         16., 11.,  0.,  0.,  0.,  0.,  0.,  2., 16., 11.,  4.,  4.,  0.,
#          0.,  0.,  2., 15., 16., 16., 14., 10.,  1.,  0.,  0.,  9., 16.,
#          7.,  3., 15.,  6.,  0.,  0.,  0.,  7., 15., 16., 16.,  6.]),
#  5.375,
#  6.3356629487370935)
