# %% [markdown]
# <a href="https://colab.research.google.com/github/Praveenpadidapu/ML-Assignments/blob/main/Blog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
data=pd.read_csv('/content/world_health_data.csv')
data
# Out:
#                           country country_code  year  health_exp  life_expect  \
# 0                           Aruba          ABW  1999         NaN    73.561000
# 1     Africa Eastern and Southern          AFE  1999         NaN    51.258874
# 2                     Afghanistan          AFG  1999         NaN    54.846000
# 3      Africa Western and Central          AFW  1999         NaN    49.726429
# 4                          Angola          AGO  1999         NaN    45.386000
# ...                           ...          ...   ...         ...          ...
# 6645                       Kosovo          XKX  2023         NaN          NaN
# 6646                  Yemen, Rep.          YEM  2023         NaN          NaN
# 6647                 South Africa          ZAF  2023         NaN          NaN
# 6648                       Zambia          ZMB  2023         NaN          NaN
# 6649                     Zimbabwe          ZWE  2023         NaN          NaN
#
# ...

# %% [markdown]
# The dataset consists of one CSV file named "world_health_data.csv" with the following columns:
#
# country: The name of the country for which the data is reported.
# country_code: The ISO country code.
# year: The year for which the data is reported.
# health_exp: Current health expenditure as a percentage of GDP.
# life_expect: Life expectancy at birth (total years) for the population.
# maternal_mortality: The number of maternal deaths per 100,000 live births.
# infant_mortality: The number of infant deaths (under 1 year) per 1,000 live births.
# neonatal_mortality: The number of deaths of children under 28 days of age per 1,000 live births.
# under_5_mortality: The number of deaths of children under 5 years of age per 1,000 live births.
# # prev_hiv: The percentage of the population aged 15-49 years living with HIV.

# %%
data.isnull().sum()
# Out:
# country                     0
# country_code                0
# year                        0
# health_exp               1483
# life_expect               460
# maternal_mortality       1757
# infant_mortality          794
# neonatal_mortality        794
# under_5_mortality         794
# prev_hiv                 2380
# inci_tuberc              1221
# prev_undernourishment    1845
# dtype: int64

# %%
mean=data.mean().mean()
mean
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-5d208b8f0174> in <cell line: 1>()
# ----> 1 mean=data.mean().mean()
#       2 mean
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# ...

# %%
data.columns
# Out:
# Index(['country', 'country_code', 'year', 'health_exp', 'life_expect',
#        'maternal_mortality', 'infant_mortality', 'neonatal_mortality',
#        'under_5_mortality', 'prev_hiv', 'inci_tuberc',
#        'prev_undernourishment'],
#       dtype='object')

# %%
columns = ['health_exp', 'life_expect',
       'maternal_mortality', 'infant_mortality', 'neonatal_mortality',
       'under_5_mortality', 'prev_hiv', 'inci_tuberc',
       'prev_undernourishment']
mean=data[columns].mean()
mean
# Out:
# health_exp                 6.200581
# life_expect               70.066531
# maternal_mortality       200.862661
# infant_mortality          28.966389
# neonatal_mortality        16.410860
# under_5_mortality         40.399681
# prev_hiv                   1.806485
# inci_tuberc              126.391393
# prev_undernourishment     11.102418
# dtype: float64

# %%
data['life_expect'].fillna(data['life_expect'].mean(),inplace=True)
data['health_exp'].fillna(data['health_exp'].mean(),inplace=True)
data['maternal_mortality'].fillna(data['maternal_mortality'].mean(),inplace=True)
data['infant_mortality'].fillna(data['infant_mortality'].mean(),inplace=True)
data['neonatal_mortality'].fillna(data['neonatal_mortality'].mean(),inplace=True)
data['under_5_mortality'].fillna(data['under_5_mortality'].mean(),inplace=True)
data['prev_hiv'].fillna(data['prev_hiv'].mean(),inplace=True)
data['inci_tuberc'].fillna(data['inci_tuberc'].mean(),inplace=True)
data['prev_undernourishment'].fillna(data['prev_undernourishment'].mean(),inplace=True)
# Out:
# <ipython-input-6-0a3de0ebcbea>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['life_expect'].fillna(data['life_expect'].mean(),inplace=True)
# <ipython-input-6-0a3de0ebcbea>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
data.isnull().sum()
# Out:
# country                  0
# country_code             0
# year                     0
# health_exp               0
# life_expect              0
# maternal_mortality       0
# infant_mortality         0
# neonatal_mortality       0
# under_5_mortality        0
# prev_hiv                 0
# inci_tuberc              0
# prev_undernourishment    0
# dtype: int64

# %%
data
# Out:
#                           country country_code  year  health_exp  life_expect  \
# 0                           Aruba          ABW  1999    6.200581    73.561000
# 1     Africa Eastern and Southern          AFE  1999    6.200581    51.258874
# 2                     Afghanistan          AFG  1999    6.200581    54.846000
# 3      Africa Western and Central          AFW  1999    6.200581    49.726429
# 4                          Angola          AGO  1999    6.200581    45.386000
# ...                           ...          ...   ...         ...          ...
# 6645                       Kosovo          XKX  2023    6.200581    70.066531
# 6646                  Yemen, Rep.          YEM  2023    6.200581    70.066531
# 6647                 South Africa          ZAF  2023    6.200581    70.066531
# 6648                       Zambia          ZMB  2023    6.200581    70.066531
# 6649                     Zimbabwe          ZWE  2023    6.200581    70.066531
#
# ...

# %%
data.isnull().sum()
# Out:
# country                  0
# country_code             0
# year                     0
# health_exp               0
# life_expect              0
# maternal_mortality       0
# infant_mortality         0
# neonatal_mortality       0
# under_5_mortality        0
# prev_hiv                 0
# inci_tuberc              0
# prev_undernourishment    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['country', 'country_code', 'year', 'health_exp', 'life_expect',
#        'maternal_mortality', 'infant_mortality', 'neonatal_mortality',
#        'under_5_mortality', 'prev_hiv', 'inci_tuberc',
#        'prev_undernourishment'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
plt.bar(data.year,data.neonatal_mortality)
plt.xlabel("Years")
plt.ylabel("Neonatal mortality")
plt.title("Neonatal mortality in different countries")
plt.show()

# %%
data1=data.sample(10)
data1
# Out:
#                     country country_code  year  health_exp  life_expect  \
# 2450               Djibouti          DJI  2008    3.615434    59.365000
# 79    Micronesia, Fed. Sts.          FSM  1999    6.200581    69.706000
# 1052          Venezuela, RB          VEN  2002    6.200581    72.662000
# 6280             Montenegro          MNE  2022    6.200581    76.187805
# 2013             Madagascar          MDG  2006    5.072038    61.315000
# 4735                Somalia          SOM  2016    6.200581    55.044000
# 6225               IDA only          IDX  2022    6.200581    65.364222
# 2508                Iceland          ISL  2008    8.340000    81.609756
# 5729              Lithuania          LTU  2020    7.480000    74.978049
# 4406                Moldova          MDA  2015    8.560000    69.240000
#
#       maternal_mortality  infant_mortality  neonatal_mortality  \
# 2450          322.000000         65.500000           38.600000
# ...

# %%
plt.bar(data.year,data1.infant_mortality)
plt.xticks(rotation=90)
plt.xlabel("country names")
plt.ylabel("infant mortality")
plt.title("infant mortality in different countries")
plt.show()

# %%
data2=data.sample(400)
data2
# Out:
#                        country country_code  year  health_exp  life_expect  \
# 1351                  Bulgaria          BGR  2004    6.890000    72.563415
# 5234               New Zealand          NZL  2018    9.035116    81.707317
# 2808                   Morocco          MAR  2009    5.273122    70.458000
# 2001       Lower middle income          LMC  2006    3.926299    64.227201
# 4099                     India          IND  2014    3.620000    69.074000
# ...                        ...          ...   ...         ...          ...
# 3704                  Tanzania          TZA  2012    5.017794    62.030000
# 916                     Jordan          JOR  2002    9.278642    72.359000
# 4447  Pre-demographic dividend          PRE  2015    3.990537    59.068861
# 3362             North America          NAC  2011   15.546026    78.923964
# 3984                     Samoa          WSM  2013    6.214779    72.391000
#
#       maternal_mortality  infant_mortality  neonatal_mortality  \
# ...

# %%
plt.pie(data1.life_expect,labels=data1.country,autopct='%1.1d%%')
plt.title("country wise life expectency")
plt.show()

# %%
data.columns
# Out:
# Index(['country', 'country_code', 'year', 'health_exp', 'life_expect',
#        'maternal_mortality', 'infant_mortality', 'neonatal_mortality',
#        'under_5_mortality', 'prev_hiv', 'inci_tuberc',
#        'prev_undernourishment'],
#       dtype='object')
